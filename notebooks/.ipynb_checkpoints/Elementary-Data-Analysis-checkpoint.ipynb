# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from src.plot import Plot

# %reload_ext nb_black
# %reload_ext autoreload
# %autoreload 2

# %%
project_directory = os.path.dirname(os.getcwd())
path_to_data = os.path.join(project_directory, "data")
path_to_data_info = os.path.join(path_to_data, "data_description.txt")

path_to_train_data = os.path.join(path_to_data, "train.csv")
path_to_test_data = os.path.join(path_to_data, "test.csv")

# %%
line_reader = read_file(path_to_data_info)
for line in line_reader:
    print(line)
# Out:
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
# ...

# %%
train_df = pd.read_csv(path_to_train_data)
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# Plot object from my custom plot class
plotter = Plot(train_df, project_directory)

# %%
plotter.plot_categorical("MSSubClass", 75)
# Out:
# Summary Statistics for categorical feature MSSubClass
# Summary Statistics for categorical class 2-STORY 1946 & NEWER
# count       299.000000
# mean     239948.501672
# std       86579.909966
# min      129000.000000
# 25%      185000.000000
# 50%      215200.000000
# 75%      268750.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# Skew Score: 2.5646911155130776 and Interpret: Positive Skew and Highly Skewed
# Kurt Score: 9.778840426336759 and Interpret: Leptokurtic: Peak is Higher and thinner than Mesokurtic and thus Lot of outliers.
# ...
#
#
# Summary Statistics for categorical class 1-STORY 1946 & NEWER ALL STYLES
# count       536.000000
# mean     185224.811567
# std       78782.189967
# min       35311.000000
# 25%      132500.000000
# 50%      159250.000000
# 75%      220000.000000
# max      611657.000000
# Name: SalePrice, dtype: float64
# Skew Score: 1.6155147713334972 and Interpret: Positive Skew and Highly Skewed
# ...

# %%
plotter.plot_categorical("MSZoning", 0)
# Out:
# Summary Statistics for categorical feature MSZoning
# Summary Statistics for categorical class Residential Low Density
# count      1151.000000
# mean     191004.994787
# std       80766.341319
# min       39300.000000
# 25%      137700.000000
# 50%      174000.000000
# 75%      224700.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# Skew Score: 1.9472780629274358 and Interpret: Positive Skew and Highly Skewed
# Kurt Score: 6.774566497973101 and Interpret: Leptokurtic: Peak is Higher and thinner than Mesokurtic and thus Lot of outliers.
# ...
#
#
# Summary Statistics for categorical class Residential Medium Density
# count       218.000000
# mean     126316.830275
# std       48521.689833
# min       37900.000000
# 25%      100000.000000
# 50%      120500.000000
# 75%      140000.000000
# max      475000.000000
# Name: SalePrice, dtype: float64
# Skew Score: 3.2639779947070338 and Interpret: Positive Skew and Highly Skewed
# ...

# %%
plotter.plot_numeric("LotFrontage")
# Out:
# Summary for numerical feature LotFrontage
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64
# Skew Score: 2.163569142324884 and Interpret: Positive Skew and Highly Skewed
# Kurt Score: 17.452867259818404 and Interpret: Leptokurtic: Peak is Higher and thinner than Mesokurtic and thus Lot of outliers.
# ...

# %%
plotter.plot_numeric("LotArea")
# Out:
# Summary for numerical feature LotArea
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64
# Skew Score: 12.207687851233496 and Interpret: Positive Skew and Highly Skewed
# Kurt Score: 203.24327101886033 and Interpret: Leptokurtic: Peak is Higher and thinner than Mesokurtic and thus Lot of outliers.
# ...

# %%
plotter.plot_categorical("Utilities", 0)
# Out:
# Summary Statistics for categorical feature Utilities
# Summary Statistics for categorical class All public Utilities (E,G,W,& S)
# count      1459.000000
# mean     180950.956820
# std       79461.599814
# min       34900.000000
# 25%      129950.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# Skew Score: 1.88179773241528 and Interpret: Positive Skew and Highly Skewed
# Kurt Score: 6.530783944619095 and Interpret: Leptokurtic: Peak is Higher and thinner than Mesokurtic and thus Lot of outliers.
# ...
#
#
# Summary Statistics for categorical class Electricity and Gas Only
# count         1.0
# mean     137500.0
# std           NaN
# min      137500.0
# 25%      137500.0
# 50%      137500.0
# 75%      137500.0
# max      137500.0
# Name: SalePrice, dtype: float64
# Skew Score: nan and Interpret: None
# Kurt Score: nan and Interpret: None
# ...

# %%
plotter.plot_categorical("OverallQual", 0)
# Out:
# Summary Statistics for categorical feature OverallQual
# Summary Statistics for categorical class Good
# count       319.000000
# mean     207716.423197
# std       44466.259414
# min       82500.000000
# 25%      179470.000000
# 50%      200141.000000
# 75%      230750.000000
# max      383970.000000
# Name: SalePrice, dtype: float64
# Skew Score: 0.7863956762582445 and Interpret: Postive Skew and Moderately Skewed
# Kurt Score: 1.3194397660806572 and Interpret: Platykurtic: Peak is lower and broader than Mesokurtic and thus Lack of outliers.
# ...
#
#
# Summary Statistics for categorical class Above Average
# count       374.000000
# mean     161603.034759
# std       36090.182933
# min       76000.000000
# 25%      139125.000000
# 50%      160000.000000
# 75%      181000.000000
# max      277000.000000
# Name: SalePrice, dtype: float64
# Skew Score: 0.35854869705479603 and Interpret: Fairly Symmetrical
# ...

# %%
plotter.plot_categorical("OverallCond", 0)
# Out:
# Summary Statistics for categorical feature OverallCond
# Summary Statistics for categorical class Average
# count       821.000000
# mean     203146.914738
# std       85117.319416
# min       34900.000000
# 25%      144000.000000
# 50%      185000.000000
# 75%      239686.000000
# max      745000.000000
# Name: SalePrice, dtype: float64
# Skew Score: 1.589215021164733 and Interpret: Positive Skew and Highly Skewed
# Kurt Score: 4.470199009240986 and Interpret: Leptokurtic: Peak is Higher and thinner than Mesokurtic and thus Lot of outliers.
# ...
#
#
# Summary Statistics for categorical class Very Good
# count        72.000000
# mean     155651.736111
# std       52375.144681
# min       84500.000000
# 25%      125375.000000
# 50%      142500.000000
# 75%      170750.000000
# max      335000.000000
# Name: SalePrice, dtype: float64
# Skew Score: 1.7017984257566003 and Interpret: Positive Skew and Highly Skewed
# ...

# %%
plotter.plot_numeric("TotalBsmtSF")
# Out:
# Summary for numerical feature TotalBsmtSF
# count    1460.000000
# mean     1057.429452
# std       438.705324
# min         0.000000
# 25%       795.750000
# 50%       991.500000
# 75%      1298.250000
# max      6110.000000
# Name: TotalBsmtSF, dtype: float64
# Skew Score: 1.5242545490627664 and Interpret: Positive Skew and Highly Skewed
# Kurt Score: 13.250483281984796 and Interpret: Leptokurtic: Peak is Higher and thinner than Mesokurtic and thus Lot of outliers.
# ...

# %%
plotter.plot_numeric("GrLivArea")
# Out:
# Summary for numerical feature GrLivArea
# count    1460.000000
# mean     1515.463699
# std       525.480383
# min       334.000000
# 25%      1129.500000
# 50%      1464.000000
# 75%      1776.750000
# max      5642.000000
# Name: GrLivArea, dtype: float64
# Skew Score: 1.3665603560164552 and Interpret: Positive Skew and Highly Skewed
# Kurt Score: 4.895120580693174 and Interpret: Leptokurtic: Peak is Higher and thinner than Mesokurtic and thus Lot of outliers.
# ...

# %%
plotter.plot_individual_numeric("SalePrice")
# Out:
# Summary for numerical feature SalePrice
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# Skew Score: 1.8828757597682129 and Interpret: Positive Skew and Highly Skewed
# Kurt Score: 6.536281860064529 and Interpret: Leptokurtic: Peak is Higher and thinner than Mesokurtic and thus Lot of outliers.
# ...

# %%
features_without_mapping_substring = list(
    filter(lambda feature: "Mapping" not in feature, list(train_df.columns))
)
train_df_without_mapping = train_df.loc[:, features_without_mapping_substring]

# %%
plotter.plot_heatmap(train_df_without_mapping)
